# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.externals.six import StringIO

#visualization
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
import pydot

# %%
pluto_mn = pd.read_csv("../pluto/MN.csv")
pluto_bx = pd.read_csv("../pluto/BX.csv")
pluto_bk = pd.read_csv("../pluto/BK.csv")
pluto_qn = pd.read_csv("../pluto/QN.csv")
pluto_si = pd.read_csv("../pluto/SI.csv")

frames = [pluto_mn, pluto_bx, pluto_bk, pluto_qn, pluto_si]
pluto_nyc = pd.concat(frames)
#pluto_nyc.to_csv('../pluto/pluto_nyc.csv')
pluto_nyc.shape
# Out:
# (859205, 86)

# %%
building_column_names = ["record","BBL","bbl_status","coreported_bbl","nyc_bin","street_number","street","borough",
                "zip","covered_building","benchmark_status","site_eui","norm_site_eui","source_eui","norm_source_eui",
                "water_intensity","water_benchmark_eligible","water_method","energy_star","total_ghg","direct_ghg",
                "indirect_ghg","building_sf","dof_gsf","primary_use","num_buildings"]
building_features = building_column_names[1:]
building_target = building_column_names[0]
building_data = pd.read_csv("../data/2015_nyc_cy2014__ll84_disclosure_data.csv",header=0,names=building_column_names)
building_data.head()
# Out:
#     record         BBL bbl_status coreported_bbl  nyc_bin street_number  \
# 0   7365.0  1009970029        NaN            NaN  1022631          1155
# 1   8139.0  1013150001        NaN            NaN  1037545           655
# 2   8604.0  1009990019        NaN            NaN  1022667           114
# 3   8841.0  1013190047        NaN            NaN  1037596           733
# 4  11809.0  1009950005        NaN            NaN  1085682          1472
#
#                  street    borough      zip covered_building      ...       \
# 0  AVENUE OF THE AMER    MANHATTAN  10036.0              Yes      ...
# 1     3 AVENUE           MANHATTAN  10017.0              Yes      ...
# 2  WEST   47 STREET      MANHATTAN  10036.0              Yes      ...
# 3     3 AVENUE           MANHATTAN  10017.0              Yes      ...
# 4  BROADWAY              MANHATTAN  10036.0              Yes      ...
#
#   water_benchmark_eligible water_method energy_star total_ghg direct_ghg  \
# 0                       No         None          90    3054.3          0
# 1                       No         None          86    2453.3          0
# 2                       No         None          84    2961.2          0
# 3                       No         None          75    2731.4          0
# 4                       No         None          61   13661.8     2557.4
#
#   indirect_ghg building_sf    dof_gsf       primary_use num_buildings
# 0       3054.3      686902   734668.0            Office           1.0
# 1       2453.3      384432   380000.0            Office           1.0
# 2       2961.2      572369   565000.0  Financial Office           1.0
# 3       2731.4      362578   405399.0            Office           1.0
# 4      11104.4     1601977  1642675.0            Office           1.0
#
# [5 rows x 26 columns]

# %%
building_data.dtypes
# Out:
# record                      float64
# BBL                           int64
# bbl_status                   object
# coreported_bbl               object
# nyc_bin                      object
# street_number                object
# street                       object
# borough                      object
# zip                         float64
# covered_building             object
# benchmark_status             object
# site_eui                     object
# norm_site_eui                object
# source_eui                   object
# norm_source_eui              object
# water_intensity              object
# water_benchmark_eligible     object
# water_method                 object
# energy_star                  object
# total_ghg                    object
# direct_ghg                   object
# indirect_ghg                 object
# building_sf                  object
# dof_gsf                     float64
# primary_use                  object
# num_buildings               float64
# dtype: object

# %%
# nyc_building_data_columns = list(building_data_join.columns.values)
# nyc_building_data_columns

# %%
convert_to_float = ["coreported_bbl","nyc_bin","street_number","site_eui","norm_site_eui","source_eui",
                    "norm_source_eui","energy_star","total_ghg","direct_ghg","indirect_ghg","building_sf"]

# %%
building_data[convert_to_float] = building_data[convert_to_float].convert_objects(convert_numeric=True)
building_data.head()
building_data.dtypes
# building_data.apply(pd.to_numeric)
# Out:
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# record                      float64
# BBL                           int64
# bbl_status                   object
# coreported_bbl               object
# nyc_bin                     float64
# street_number               float64
# street                       object
# borough                      object
# zip                         float64
# covered_building             object
# benchmark_status             object
# site_eui                    float64
# norm_site_eui               float64
# source_eui                  float64
# norm_source_eui             float64
# water_intensity              object
# water_benchmark_eligible     object
# water_method                 object
# energy_star                 float64
# total_ghg                   float64
# direct_ghg                  float64
# indirect_ghg                float64
# building_sf                 float64
# dof_gsf                     float64
# primary_use                  object
# num_buildings               float64
# dtype: object

# %%
building_data.isnull().head()
building_data.isnull().sum()
# Out:
# record                       2170
# BBL                             0
# bbl_status                  13306
# coreported_bbl              13306
# nyc_bin                      3969
# street_number                2711
# street                        296
# borough                         0
# zip                          2360
# covered_building                0
# benchmark_status                0
# site_eui                     3364
# norm_site_eui                5262
# source_eui                   3364
# norm_source_eui              5262
# water_intensity              2058
# water_benchmark_eligible        0
# water_method                    0
# energy_star                  5468
# total_ghg                    3285
# direct_ghg                   3175
# indirect_ghg                 2982
# building_sf                  2672
# dof_gsf                       296
# primary_use                   296
# num_buildings                 296
# dtype: int64

# %%
building_data_columns = list(building_data.columns.values)
building_data_columns = building_data_columns[:2]+building_data_columns[4:5]+building_data_columns[11:15]+building_data_columns[18:24]+building_data_columns[-1:]+building_data_columns[2:4]+building_data_columns[5:11]+building_data_columns[15:18]+building_data_columns[-2:-1]
building_data_columns
# Out:
# ['record',
#  'BBL',
#  'nyc_bin',
#  'site_eui',
#  'norm_site_eui',
#  'source_eui',
#  'norm_source_eui',
#  'energy_star',
#  'total_ghg',
#  'direct_ghg',
#  'indirect_ghg',
#  'building_sf',
#  'dof_gsf',
#  'num_buildings',
#  'bbl_status',
#  'coreported_bbl',
#  'street_number',
#  'street',
#  'borough',
#  'zip',
#  'covered_building',
#  'benchmark_status',
#  'water_intensity',
#  'water_benchmark_eligible',
#  'water_method',
#  'primary_use']

# %%
building_data = building_data[building_data_columns]
target = building_data['primary_use']
print building_data.dtypes
building_data.head()
# Out:
# record                      float64
# BBL                           int64
# nyc_bin                     float64
# site_eui                    float64
# norm_site_eui               float64
# source_eui                  float64
# norm_source_eui             float64
# energy_star                 float64
# total_ghg                   float64
# direct_ghg                  float64
# indirect_ghg                float64
# building_sf                 float64
# dof_gsf                     float64
# num_buildings               float64
# bbl_status                   object
# coreported_bbl               object
# street_number               float64
# street                       object
# borough                      object
# zip                         float64
# covered_building             object
# benchmark_status             object
# water_intensity              object
# water_benchmark_eligible     object
# water_method                 object
# primary_use                  object
# dtype: object
#     record         BBL    nyc_bin  site_eui  norm_site_eui  source_eui  \
# 0   7365.0  1009970029  1022631.0      54.0           54.2       166.1
# 1   8139.0  1013150001  1037545.0      85.3           83.4       186.8
# 2   8604.0  1009990019  1022667.0      67.1           63.2       164.6
# 3   8841.0  1013190047  1037596.0     100.6           96.6       220.7
# 4  11809.0  1009950005  1085682.0     114.7          113.6       287.0
#
#    norm_source_eui  energy_star  total_ghg  direct_ghg        ...         \
# 0            166.8         90.0     3054.3         0.0        ...
# 1            184.1         86.0     2453.3         0.0        ...
# 2            159.4         84.0     2961.2         0.0        ...
# 3            215.0         75.0     2731.4         0.0        ...
# 4            285.8         61.0    13661.8      2557.4        ...
#
#    street_number                street    borough      zip covered_building  \
# 0         1155.0  AVENUE OF THE AMER    MANHATTAN  10036.0              Yes
# 1          655.0     3 AVENUE           MANHATTAN  10017.0              Yes
# 2          114.0  WEST   47 STREET      MANHATTAN  10036.0              Yes
# 3          733.0     3 AVENUE           MANHATTAN  10017.0              Yes
# 4         1472.0  BROADWAY              MANHATTAN  10036.0              Yes
#
#   benchmark_status  water_intensity water_benchmark_eligible water_method  \
# 0   In Compliance     Not Available                       No         None
# 1   In Compliance     Not Available                       No         None
# 2   In Compliance     Not Available                       No         None
# 3   In Compliance     Not Available                       No         None
# 4   In Compliance     Not Available                       No         None
#
#         primary_use
# 0            Office
# 1            Office
# 2  Financial Office
# 3            Office
# 4            Office
#
# [5 rows x 26 columns]

# %%
print building_data[building_data_columns[:14]].head(30)
median_per_column = building_data[building_data_columns[3:14]].apply(lambda x: x.median(),axis=0)
print "Median per column:\n",median_per_column
# Out:
#        record         BBL    nyc_bin  site_eui  norm_site_eui  source_eui  \
# 0      7365.0  1009970029  1022631.0      54.0           54.2       166.1
# 1      8139.0  1013150001  1037545.0      85.3           83.4       186.8
# 2      8604.0  1009990019  1022667.0      67.1           63.2       164.6
# 3      8841.0  1013190047  1037596.0     100.6           96.6       220.7
# 4     11809.0  1009950005  1085682.0     114.7          113.6       287.0
# 5     13286.0  1013160001        NaN      97.7           95.2       204.3
# 6   1025339.0  1012980023  1036162.0      85.3           82.7       225.9
# 7   1045358.0  1012860035  1035464.0      93.0           91.3       248.2
# 8   1052478.0  1000480001  1001027.0     132.9          129.0       269.1
# 9   1069082.0  1008560024  1016880.0     100.6           96.7       215.7
# 10  1143922.0  1000350010  1000868.0      66.1           63.6       176.5
# 11  1143934.0  1001860001  1082816.0      78.8           78.8       202.6
# 12  1151970.0  1009960029  1080824.0     110.8          108.7       243.8
# 13  1160595.0  5024000210        NaN      53.2           52.4       150.2
# 14  1160893.0  2051410003        NaN      56.9           55.8       157.3
# 15  1160897.0  4018600102        NaN      63.1           62.6       179.0
# 16  1172592.0  1013030033  1036228.0      80.6           78.6       210.5
# 17  1180593.0  4093640010  4440535.0      46.3            NaN        48.6
# 18  1192662.0  1012617501  1071414.0     115.1          114.9       228.0
# 19  1200524.0  1013000033  1036195.0      91.5           90.0       227.7
# 20  1210636.0  1012870021  1035471.0      41.1            NaN       103.2
# 21  1211581.0  1013090001  1036476.0      77.1            NaN       188.8
# 22  1217055.0  1008547501        NaN      77.7           76.2       203.6
# 23  1230053.0  1010277504        NaN      79.9           78.9       224.7
# 24  1230813.0  1014637501  1045575.0     511.9          503.3      1101.7
# 25  1230818.0  1014610013  1045570.0     441.4          432.1       932.3
# 26  1231058.0  1012890014  1035727.0      84.3            NaN       229.8
# 27  1261446.0  1000627501  1001068.0     107.6          106.1       261.3
# 28  1261447.0  1010497501  1026318.0     154.9            NaN       362.9
# 29  1261451.0  1000047501  1000005.0     149.0          149.0       358.8
#
#     norm_source_eui  energy_star  total_ghg  direct_ghg  indirect_ghg  \
# 0             166.8         90.0     3054.3         0.0        3054.3
# 1             184.1         86.0     2453.3         0.0        2453.3
# 2             159.4         84.0     2961.2         0.0        2961.2
# 3             215.0         75.0     2731.4         0.0        2731.4
# 4             285.8         61.0    13661.8      2557.4       11104.4
# 5             201.5         66.0     5436.0         0.0        5436.0
# 6             221.5         72.0     4982.7        56.2        4926.5
# 7             245.5         79.0     5298.3         0.0        5298.3
# 8             264.5         68.0    12402.5        26.5       12375.9
# 9             211.3         78.0    11334.2         0.0       11334.2
# 10            173.4          NaN     4675.5        87.2        4588.3
# 11            202.6         78.0    11474.5       131.3       11343.2
# 12            241.2         76.0     8112.3         0.0        8112.3
# 13            149.3         76.0      747.7        77.4         670.3
# 14            156.2         85.0      734.0        90.0         644.0
# 15            178.9         80.0     1013.5        99.5         914.1
# 16            207.5         79.0     3056.8       104.1        2952.8
# 17              NaN        100.0      323.4       323.4           0.0
# 18            227.3         63.0    15118.2         0.0       15118.2
# 19            226.1         84.0     4445.4         0.0        4445.4
# 20              NaN         97.0      980.0         0.0         980.0
# 21              NaN         71.0     3499.0         0.0        3499.0
# 22            201.9         90.0    15889.6       221.5       15668.1
# 23            223.9         71.0     4074.9       432.9        3642.0
# 24           1095.2          NaN    28370.0         0.0       28370.0
# 25            922.7          NaN    10736.4         0.0       10736.4
# 26              NaN         74.0     6846.1       142.1        6704.1
# 27            259.4         84.0    19360.4        91.4       19269.0
# 28              NaN          NaN    31804.9      1406.0       30398.8
# 29            358.8         61.0    28473.3         0.1       28473.2
#
#     building_sf    dof_gsf  num_buildings
# 0      686902.0   734668.0            1.0
# 1      384432.0   380000.0            1.0
# 2      572369.0   565000.0            1.0
# 3      362578.0   405399.0            1.0
# 4     1601977.0  1642675.0            1.0
# 5      752426.0   289356.0            1.0
# 6      743915.0   627691.0            1.0
# 7      721979.0   656436.0            1.0
# 8     1272119.0  1141266.0            1.0
# 9     1513807.0  1159795.0            1.0
# 10     893647.0   990250.0            1.0
# 11    1869756.0  1594289.0            1.0
# 12     977035.0  1039529.0            2.0
# 13     179200.0   179200.0            1.0
# 14     166320.0   170513.0            1.0
# 15     204340.0   202383.0            1.0
# 16     487501.0   490020.0            1.0
# 17     131610.0   484470.0            2.0
# 18    1797825.0  1529036.0            1.0
# 19     627731.0   665110.0            1.0
# 20     307384.0   262287.0            1.0
# 21     161427.0   136044.0            1.0
# 22    2613986.0  1587500.0            1.0
# 23     651851.0   200000.0            1.0
# 24     743935.0   731550.0            1.0
# 25     327993.0   228637.0            1.0
# 26    1027741.0   916586.0            1.0
# 27    2342856.0  2139035.0            1.0
# 28    2722590.0  2797249.0            1.0
# 29    2428325.0  2542563.0            1.0
# Median per column:
# site_eui              86.10
# norm_site_eui         82.50
# source_eui           132.30
# norm_source_eui      129.30
# energy_star           59.00
# total_ghg            553.40
# direct_ghg           329.10
# indirect_ghg         153.95
# building_sf        96157.00
# dof_gsf            94828.00
# num_buildings          1.00
# dtype: float64

# %%
numeric_median_filled = building_data[building_data_columns[3:14]].fillna(median_per_column,axis=0)
numeric_median_filled.head(30)
# Out:
#     site_eui  norm_site_eui  source_eui  norm_source_eui  energy_star  \
# 0       54.0           54.2       166.1            166.8         90.0
# 1       85.3           83.4       186.8            184.1         86.0
# 2       67.1           63.2       164.6            159.4         84.0
# 3      100.6           96.6       220.7            215.0         75.0
# 4      114.7          113.6       287.0            285.8         61.0
# 5       97.7           95.2       204.3            201.5         66.0
# 6       85.3           82.7       225.9            221.5         72.0
# 7       93.0           91.3       248.2            245.5         79.0
# 8      132.9          129.0       269.1            264.5         68.0
# 9      100.6           96.7       215.7            211.3         78.0
# 10      66.1           63.6       176.5            173.4         59.0
# 11      78.8           78.8       202.6            202.6         78.0
# 12     110.8          108.7       243.8            241.2         76.0
# 13      53.2           52.4       150.2            149.3         76.0
# 14      56.9           55.8       157.3            156.2         85.0
# 15      63.1           62.6       179.0            178.9         80.0
# 16      80.6           78.6       210.5            207.5         79.0
# 17      46.3           82.5        48.6            129.3        100.0
# 18     115.1          114.9       228.0            227.3         63.0
# 19      91.5           90.0       227.7            226.1         84.0
# 20      41.1           82.5       103.2            129.3         97.0
# 21      77.1           82.5       188.8            129.3         71.0
# 22      77.7           76.2       203.6            201.9         90.0
# 23      79.9           78.9       224.7            223.9         71.0
# 24     511.9          503.3      1101.7           1095.2         59.0
# 25     441.4          432.1       932.3            922.7         59.0
# 26      84.3           82.5       229.8            129.3         74.0
# 27     107.6          106.1       261.3            259.4         84.0
# 28     154.9           82.5       362.9            129.3         59.0
# 29     149.0          149.0       358.8            358.8         61.0
#
#     total_ghg  direct_ghg  indirect_ghg  building_sf    dof_gsf  num_buildings
# 0      3054.3         0.0        3054.3     686902.0   734668.0            1.0
# 1      2453.3         0.0        2453.3     384432.0   380000.0            1.0
# 2      2961.2         0.0        2961.2     572369.0   565000.0            1.0
# 3      2731.4         0.0        2731.4     362578.0   405399.0            1.0
# 4     13661.8      2557.4       11104.4    1601977.0  1642675.0            1.0
# 5      5436.0         0.0        5436.0     752426.0   289356.0            1.0
# 6      4982.7        56.2        4926.5     743915.0   627691.0            1.0
# 7      5298.3         0.0        5298.3     721979.0   656436.0            1.0
# 8     12402.5        26.5       12375.9    1272119.0  1141266.0            1.0
# 9     11334.2         0.0       11334.2    1513807.0  1159795.0            1.0
# 10     4675.5        87.2        4588.3     893647.0   990250.0            1.0
# 11    11474.5       131.3       11343.2    1869756.0  1594289.0            1.0
# 12     8112.3         0.0        8112.3     977035.0  1039529.0            2.0
# 13      747.7        77.4         670.3     179200.0   179200.0            1.0
# 14      734.0        90.0         644.0     166320.0   170513.0            1.0
# 15     1013.5        99.5         914.1     204340.0   202383.0            1.0
# 16     3056.8       104.1        2952.8     487501.0   490020.0            1.0
# 17      323.4       323.4           0.0     131610.0   484470.0            2.0
# 18    15118.2         0.0       15118.2    1797825.0  1529036.0            1.0
# 19     4445.4         0.0        4445.4     627731.0   665110.0            1.0
# 20      980.0         0.0         980.0     307384.0   262287.0            1.0
# 21     3499.0         0.0        3499.0     161427.0   136044.0            1.0
# 22    15889.6       221.5       15668.1    2613986.0  1587500.0            1.0
# 23     4074.9       432.9        3642.0     651851.0   200000.0            1.0
# 24    28370.0         0.0       28370.0     743935.0   731550.0            1.0
# 25    10736.4         0.0       10736.4     327993.0   228637.0            1.0
# 26     6846.1       142.1        6704.1    1027741.0   916586.0            1.0
# 27    19360.4        91.4       19269.0    2342856.0  2139035.0            1.0
# 28    31804.9      1406.0       30398.8    2722590.0  2797249.0            1.0
# 29    28473.3         0.1       28473.2    2428325.0  2542563.0            1.0

# %%
def get_most_frequent_value(my_column):
    return my_column.value_counts().index[0]

most_frequent_values_per_column = building_data[building_data_columns[-1:]].apply(get_most_frequent_value,axis=0)
print "Most frequent value in each column:\n",most_frequent_values_per_column

categorical_most_frequent = building_data[building_data_columns[-1:]].fillna(most_frequent_values_per_column,axis=0)
categorical_most_frequent.head()
# Out:
# Most frequent value in each column:
# primary_use    Multifamily Housing
# dtype: object
#         primary_use
# 0            Office
# 1            Office
# 2  Financial Office
# 3            Office
# 4            Office

# %%
building_data_numeric_columns = building_data.columns.tolist()[3:14]
building_data_categorical_columns = building_data.columns.tolist()[-1:]
building_data_filled = building_data.copy()
building_data_filled[building_data_numeric_columns] = numeric_median_filled
building_data_filled[building_data_categorical_columns] = categorical_most_frequent
building_data_filled.isnull().sum()
# Out:
# record                       2170
# BBL                             0
# nyc_bin                      3969
# site_eui                        0
# norm_site_eui                   0
# source_eui                      0
# norm_source_eui                 0
# energy_star                     0
# total_ghg                       0
# direct_ghg                      0
# indirect_ghg                    0
# building_sf                     0
# dof_gsf                         0
# num_buildings                   0
# bbl_status                  13306
# coreported_bbl              13306
# street_number                2711
# street                        296
# borough                         0
# zip                          2360
# covered_building                0
# benchmark_status                0
# water_intensity              2058
# water_benchmark_eligible        0
# water_method                    0
# primary_use                     0
# dtype: int64

# %%
building_data_filled['dof_gsf'].hist(bins=100)

# %%
x = building_data['dof_gsf']
y = building_data['total_ghg']

plt.scatter(x, y)
plt.show()

# %%
building_data_join = pd.merge(building_data_filled, pluto_nyc, how='inner', on='BBL')
building_data_join.head()
building_data_join.shape
# Out:
# (13874, 111)

# %%
nyc_building_data_columns = list(building_data_join.columns.values)
nyc_building_data_columns
# Out:
# ['record',
#  'BBL',
#  'nyc_bin',
#  'site_eui',
#  'norm_site_eui',
#  'source_eui',
#  'norm_source_eui',
#  'energy_star',
#  'total_ghg',
#  'direct_ghg',
#  'indirect_ghg',
#  'building_sf',
#  'dof_gsf',
#  'num_buildings',
#  'bbl_status',
#  'coreported_bbl',
#  'street_number',
#  'street',
#  'borough',
#  'zip',
#  'covered_building',
#  'benchmark_status',
#  'water_intensity',
#  'water_benchmark_eligible',
#  'water_method',
#  'primary_use',
#  'Borough',
#  'Block',
#  'Lot',
#  'CD',
#  'CT2010',
#  'CB2010',
#  'SchoolDist',
#  'Council',
#  'ZipCode',
#  'FireComp',
#  'PolicePrct',
#  'HealthArea',
#  'SanitBoro',
#  'SanitDistrict',
#  'SanitSub',
#  'Address',
#  'ZoneDist1',
#  'ZoneDist2',
#  'ZoneDist3',
#  'ZoneDist4',
#  'Overlay1',
#  'Overlay2',
#  'SPDist1',
#  'SPDist2',
#  'LtdHeight',
#  'AllZoning1',
#  'AllZoning2',
#  'SplitZone',
#  'BldgClass',
#  'LandUse',
#  'Easements',
#  'OwnerType',
#  'OwnerName',
#  'LotArea',
#  'BldgArea',
#  'ComArea',
#  'ResArea',
#  'OfficeArea',
#  'RetailArea',
#  'GarageArea',
#  'StrgeArea',
#  'FactryArea',
#  'OtherArea',
#  'AreaSource',
#  'NumBldgs',
#  'NumFloors',
#  'UnitsRes',
#  'UnitsTotal',
#  'LotFront',
#  'LotDepth',
#  'BldgFront',
#  'BldgDepth',
#  'Ext',
#  'ProxCode',
#  'IrrLotCode',
#  'LotType',
#  'BsmtCode',
#  'AssessLand',
#  'AssessTot',
#  'ExemptLand',
#  'ExemptTot',
#  'YearBuilt',
#  'BuiltCode',
#  'YearAlter1',
#  'YearAlter2',
#  'HistDist',
#  'Landmark',
#  'BuiltFAR',
#  'ResidFAR',
#  'CommFAR',
#  'FacilFAR',
#  'BoroCode',
#  'CondoNo',
#  'Tract2010',
#  'XCoord',
#  'YCoord',
#  'ZoneMap',
#  'ZMCode',
#  'Sanborn',
#  'TaxMap',
#  'EDesigNum',
#  'APPBBL',
#  'APPDate',
#  'PLUTOMapID',
#  'Version']

# %%
building_data_join.dtypes
# Out:
# record                      float64
# BBL                           int64
# nyc_bin                     float64
# site_eui                    float64
# norm_site_eui               float64
# source_eui                  float64
# norm_source_eui             float64
# energy_star                 float64
# total_ghg                   float64
# direct_ghg                  float64
# indirect_ghg                float64
# building_sf                 float64
# dof_gsf                     float64
# num_buildings               float64
# bbl_status                   object
# coreported_bbl               object
# street_number               float64
# street                       object
# borough                      object
# zip                         float64
# covered_building             object
# benchmark_status             object
# water_intensity              object
# water_benchmark_eligible     object
# water_method                 object
# primary_use                  object
# Borough                      object
# Block                         int64
# Lot                           int64
# CD                            int64
#                              ...
# LotType                     float64
# BsmtCode                    float64
# AssessLand                    int64
# AssessTot                     int64
# ExemptLand                    int64
# ExemptTot                     int64
# YearBuilt                     int64
# BuiltCode                    object
# YearAlter1                    int64
# YearAlter2                    int64
# HistDist                     object
# Landmark                     object
# BuiltFAR                    float64
# ResidFAR                    float64
# CommFAR                     float64
# FacilFAR                    float64
# BoroCode                      int64
# CondoNo                       int64
# Tract2010                     int64
# XCoord                      float64
# YCoord                      float64
# ZoneMap                      object
# ZMCode                       object
# Sanborn                      object
# TaxMap                      float64
# EDesigNum                    object
# APPBBL                      float64
# APPDate                      object
# PLUTOMapID                    int64
# Version                      object
# dtype: object

# %%
building_data_join.head()
# Out:
#     record         BBL    nyc_bin  site_eui  norm_site_eui  source_eui  \
# 0   7365.0  1009970029  1022631.0      54.0           54.2       166.1
# 1   8139.0  1013150001  1037545.0      85.3           83.4       186.8
# 2   8604.0  1009990019  1022667.0      67.1           63.2       164.6
# 3   8841.0  1013190047  1037596.0     100.6           96.6       220.7
# 4  11809.0  1009950005  1085682.0     114.7          113.6       287.0
#
#    norm_source_eui  energy_star  total_ghg  direct_ghg   ...       YCoord  \
# 0            166.8         90.0     3054.3         0.0   ...     214936.0
# 1            184.1         86.0     2453.3         0.0   ...     212622.0
# 2            159.4         84.0     2961.2         0.0   ...     215488.0
# 3            215.0         75.0     2731.4         0.0   ...     213575.0
# 4            285.8         61.0    13661.8      2557.4   ...     214716.0
#
#    ZoneMap  ZMCode  Sanborn   TaxMap EDesigNum        APPBBL    APPDate  \
# 0       8d     NaN  105N048  10401.0       NaN  0.000000e+00        NaN
# 1       8d     NaN  104 033  10506.0       NaN  0.000000e+00        NaN
# 2       8d     NaN  105N059  10401.0       NaN  1.009990e+09   3/9/1988
# 3       8d     NaN  104 034  10506.0       NaN  0.000000e+00        NaN
# 4       8d     NaN  105N047  10401.0       NaN  1.009950e+09  3/16/2004
#
#   PLUTOMapID  Version
# 0          1     16v1
# 1          1     16v1
# 2          1     16v1
# 3          1     16v1
# 4          1     16v1
#
# [5 rows x 111 columns]

# %%
x_join = building_data_join['LotArea']
y_join = building_data_join['total_ghg']

plt.scatter(x_join, y_join)
plt.show()

# %%
columns_to_plot = ['norm_site_eui','norm_source_eui','energy_star','total_ghg','direct_ghg','indirect_ghg','dof_gsf',
                   'LotArea','YearBuilt','BuiltFAR','ResidFAR','CommFAR','FacilFAR']
building_data_abbrev = building_data_join[columns_to_plot]
building_data_abbrev.head()
# Out:
#    norm_site_eui  norm_source_eui  energy_star  total_ghg  direct_ghg  \
# 0           54.2            166.8         90.0     3054.3         0.0
# 1           83.4            184.1         86.0     2453.3         0.0
# 2           63.2            159.4         84.0     2961.2         0.0
# 3           96.6            215.0         75.0     2731.4         0.0
# 4          113.6            285.8         61.0    13661.8      2557.4
#
#    indirect_ghg    dof_gsf  LotArea  YearBuilt  BuiltFAR  ResidFAR  CommFAR  \
# 0        3054.3   734668.0    33639       1984     21.84      10.0     15.0
# 1        2453.3   380000.0    18993       1958     20.01      10.0     15.0
# 2        2961.2   565000.0    26100       1987     21.65      10.0     12.0
# 3        2731.4   405399.0    25768       1960     15.73      10.0     15.0
# 4       11104.4  1642675.0    45800       1998     35.87      10.0     15.0
#
#    FacilFAR
# 0      15.0
# 1      15.0
# 2      12.0
# 3      15.0
# 4      15.0

# %%
sns.pairplot(building_data_abbrev)

# %%
print building_data.shape
print 'total greenhouse gas emissions: \n', building_data['total_ghg'].describe()
print 'indirect greenhouse gas emissions: \n', building_data['indirect_ghg'].describe()
print 'energy star ratings: \n', building_data['energy_star'].describe()
print 'square footage of buildings reporting: \n', building_data['dof_gsf'].describe()
print 'primary property type: \n', building_data['primary_use'].describe()
# Out:
# (13974, 26)
# total greenhouse gas emissions:
# count    1.068900e+04
# mean     1.668260e+04
# std      7.749364e+05
# min      0.000000e+00
# 25%      3.611000e+02
# 50%      5.534000e+02
# 75%      1.026100e+03
# max      6.052160e+07
# Name: total_ghg, dtype: float64
# indirect greenhouse gas emissions:
# count    1.099200e+04
# mean     1.548464e+04
# std      7.640136e+05
# min      0.000000e+00
# 25%      8.370000e+01
# 50%      1.539500e+02
# 75%      4.075750e+02
# max      6.052160e+07
# Name: indirect_ghg, dtype: float64
# energy star ratings:
# count    8506.000000
# mean       55.346932
# std        30.156627
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%        81.000000
# max       100.000000
# Name: energy_star, dtype: float64
# square footage of buildings reporting:
# count    1.367800e+04
# mean     1.803697e+05
# std      4.754714e+05
# min      5.000800e+04
# 25%      6.540000e+04
# 50%      9.482800e+04
# 75%      1.650912e+05
# max      2.760000e+07
# Name: dof_gsf, dtype: float64
# primary property type:
# count                   13678
# unique                     51
# top       Multifamily Housing
# freq                     8552
# Name: primary_use, dtype: object

# %%
sns.plt.hist(building_data.total_ghg)
sns.plt.xlabel("Emissions")
sns.plt.ylabel("Number of Buildings")
# plt.title("Total Greenhouse Gas Emissions")
# plt.ylabel("Number of Buildings")
# plt.xlabel("Emissions")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-fb72d4e40a13> in <module>()
# ----> 1 sns.plt.hist(building_data.total_ghg)
#       2 sns.plt.xlabel("Emissions")
#       3 sns.plt.ylabel("Number of Buildings")
#       4 # plt.title("Total Greenhouse Gas Emissions")
#       5 # plt.ylabel("Number of Buildings")
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     174         if (mn > mx):
#     175             raise AttributeError(
# --> 176                 'max must be larger than min in range parameter.')
#     177
#     178     # Histogram is an integer or a float array depending on the weights.
#
# AttributeError: max must be larger than min in range parameter.

# %%
#sns.pairplot(buildingData[feature_names_buildings+['total_ghg_emissions\r_mtco2e_']],hue="total_ghg_emissions\r_mtco2e_", palette='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-80990ad7d640> in <module>()
# ----> 1 sns.pairplot(buildingData[feature_names_buildings+['total_ghg_emissions\r_mtco2e_']],hue="total_ghg_emissions\r_mtco2e_", palette='coolwarm')
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1583                     hue_order=hue_order, palette=palette,
#    1584                     diag_sharey=diag_sharey,
# -> 1585                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    1586
#    1587     # Add the markers here as PairGrid has figured out how many levels of the
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
#    1221                                       index=data.index)
#    1222         else:
# -> 1223             hue_names = utils.categorical_order(data[hue], hue_order)
#    1224             if dropna:
#    1225                 # Filter NA from the list of unique hue names
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/seaborn/utils.pyc in categorical_order(values, order)
#     521                     order = values.unique()
#     522                 except AttributeError:
# --> 523                     order = pd.unique(values)
#     524                 try:
#     525                     np.asarray(values).astype(np.float)
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/pandas/core/algorithms.pyc in unique(values)
#      66     uniques
#      67     """
# ---> 68     values = com._asarray_tuplesafe(values)
#      69
#      70     f = lambda htype, caster: _unique_generic(values, htype, caster)
#
# /Users/zlatakobzantsev/anaconda/lib/python2.7/site-packages/pandas/core/common.pyc in _asarray_tuplesafe(values, dtype)
#    2117             except ValueError:
#    2118                 # we have a list-of-list
# -> 2119                 result[:] = [tuple(x) for x in values]
#    2120
#    2121     return result
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 13974
